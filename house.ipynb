# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('kc_house_data.csv')
data
# Out:
#                id             date  ...  sqft_living15  sqft_lot15
# 0      7129300520  20141013T000000  ...           1340        5650
# 1      6414100192  20141209T000000  ...           1690        7639
# 2      5631500400  20150225T000000  ...           2720        8062
# 3      2487200875  20141209T000000  ...           1360        5000
# 4      1954400510  20150218T000000  ...           1800        7503
# ...           ...              ...  ...            ...         ...
# 21608   263000018  20140521T000000  ...           1530        1509
# 21609  6600060120  20150223T000000  ...           1830        7200
# 21610  1523300141  20140623T000000  ...           1020        2007
# 21611   291310100  20150116T000000  ...           1410        1287
# 21612  1523300157  20141015T000000  ...           1020        1357
#
# [21613 rows x 21 columns]

# %%
data.head()
# Out:
#            id             date     price  ...     long  sqft_living15  sqft_lot15
# 0  7129300520  20141013T000000  221900.0  ... -122.257           1340        5650
# 1  6414100192  20141209T000000  538000.0  ... -122.319           1690        7639
# 2  5631500400  20150225T000000  180000.0  ... -122.233           2720        8062
# 3  2487200875  20141209T000000  604000.0  ... -122.393           1360        5000
# 4  1954400510  20150218T000000  510000.0  ... -122.045           1800        7503
#
# [5 rows x 21 columns]

# %%
cor=data.corr()
cor
# Out:
#                      id     price  ...  sqft_living15  sqft_lot15
# id             1.000000 -0.016762  ...      -0.002901   -0.138798
# price         -0.016762  1.000000  ...       0.585379    0.082447
# bedrooms       0.001286  0.308350  ...       0.391638    0.029244
# bathrooms      0.005160  0.525138  ...       0.568634    0.087175
# sqft_living   -0.012258  0.702035  ...       0.756420    0.183286
# sqft_lot      -0.132109  0.089661  ...       0.144608    0.718557
# floors         0.018525  0.256794  ...       0.279885   -0.011269
# waterfront    -0.002721  0.266369  ...       0.086463    0.030703
# view           0.011592  0.397293  ...       0.280439    0.072575
# condition     -0.023783  0.036362  ...      -0.092824   -0.003406
# grade          0.008130  0.667434  ...       0.713202    0.119248
# sqft_above    -0.010842  0.605567  ...       0.731870    0.194050
# sqft_basement -0.005151  0.323816  ...       0.200355    0.017276
# yr_built       0.021380  0.054012  ...       0.326229    0.070958
# yr_renovated  -0.016907  0.126434  ...      -0.002673    0.007854
# zipcode       -0.008224 -0.053203  ...      -0.279033   -0.147221
# lat           -0.001891  0.307003  ...       0.048858   -0.086419
# long           0.020799  0.021626  ...       0.334605    0.254451
# sqft_living15 -0.002901  0.585379  ...       1.000000    0.183192
# sqft_lot15    -0.138798  0.082447  ...       0.183192    1.000000
#
# [20 rows x 20 columns]

# %%
abs(cor.loc['sqft_lot15']).sort_values(ascending=False)
# Out:
# sqft_lot15       1.000000
# sqft_lot         0.718557
# long             0.254451
# sqft_above       0.194050
# sqft_living      0.183286
# sqft_living15    0.183192
# zipcode          0.147221
# id               0.138798
# grade            0.119248
# bathrooms        0.087175
# lat              0.086419
# price            0.082447
# view             0.072575
# yr_built         0.070958
# waterfront       0.030703
# bedrooms         0.029244
# sqft_basement    0.017276
# floors           0.011269
# yr_renovated     0.007854
# condition        0.003406
# Name: sqft_lot15, dtype: float64

# %%
data1=data.drop(['id'],axis=1)
data1
# Out:
#                   date     price  bedrooms  ...     long  sqft_living15  sqft_lot15
# 0      20141013T000000  221900.0         3  ... -122.257           1340        5650
# 1      20141209T000000  538000.0         3  ... -122.319           1690        7639
# 2      20150225T000000  180000.0         2  ... -122.233           2720        8062
# 3      20141209T000000  604000.0         4  ... -122.393           1360        5000
# 4      20150218T000000  510000.0         3  ... -122.045           1800        7503
# ...                ...       ...       ...  ...      ...            ...         ...
# 21608  20140521T000000  360000.0         3  ... -122.346           1530        1509
# 21609  20150223T000000  400000.0         4  ... -122.362           1830        7200
# 21610  20140623T000000  402101.0         2  ... -122.299           1020        2007
# 21611  20150116T000000  400000.0         3  ... -122.069           1410        1287
# 21612  20141015T000000  325000.0         2  ... -122.299           1020        1357
#
# [21613 rows x 20 columns]

# %%
x=data['sqft_lot']
y=data['price']
x=np.array(x/x.mean())
y=np.array(y/y.mean())

# %%
print(np.shape(x),np.shape(y))
# Out:
# (21613,) (21613,)

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2)
print(np.shape(xtrain),np.shape(xtest))
# Out:
# (17290,) (4323,)

# %%
plt.plot(xtrain,ytrain,'b.')

# %%
plt.plot(xtest, ytest, 'g.')

# %%
def hypothesis(a,b,x):
  return a*x + b

# %%
def error(a,b,x,y):
  e = 0
  m = len(y)
  for i in range(m):
    e += np.power((hypothesis(a,b,x[i])-y[i]),2)
  return (1/(2*m)) *e

# %%
def step_gradiet(a,b,x,y,learning_rate):
  grad_a = 0
  grad_b = 0
  m = len(x)
  for i in range(m):
    grad_a += 1/m * (hypothesis(a,b,x[i])-y[i]) *x[i]
    grad_b += 1/m * (hypothesis(a,b,x[i])-y[i])
  a = a- (grad_a * learning_rate)
  b = b- (grad_b * learning_rate)
  return a,b

# %%
def descend(initial_a, initial_b, x,y,learning_rate, iterations):
  a = initial_a
  b = initial_b
  for i in range(iterations):
    e = error(a,b,x,y)
    if i % 1000 ==0:
      print(f"Error: {e}, a: {a}, b: {b}")
    a,b = step_gradiet(a,b,x,y,learning_rate)
  return a,b

# %%
a = 0
b = 1
learning_rate = 0.01
iterations = 10000
final_a, final_b = descend(a,b,xtrain, ytrain, learning_rate, iterations)
# Out:
# Error: 0.23724077138150343, a: 0, b: 1
# Error: 0.2353679151634186, a: 0.022795595238079523, b: 0.9808875617285662
# Error: 0.2353679151575243, a: 0.022796091438776308, b: 0.980883905081406
# Error: 0.23536791515752412, a: 0.022796091521990813, b: 0.9808839044681742
# Error: 0.23536791515752364, a: 0.022796091522003972, b: 0.9808839044680776
# Error: 0.23536791515752364, a: 0.022796091522003972, b: 0.9808839044680776
# Error: 0.23536791515752364, a: 0.022796091522003972, b: 0.9808839044680776
# Error: 0.23536791515752364, a: 0.022796091522003972, b: 0.9808839044680776
# Error: 0.23536791515752364, a: 0.022796091522003972, b: 0.9808839044680776
# Error: 0.23536791515752364, a: 0.022796091522003972, b: 0.9808839044680776

# %%
print(error(a,b,xtrain, ytrain))
print(error(final_a,final_b, xtrain, ytrain))
# Out:
# 0.23724077138150343
# 0.23536791515752364

# %%
err=error(final_a, final_b, xtest, ytest)
err
# Out:
# 0.20439615981047451

# %%
plt.plot(xtest, ytest, 'r.', xtest, hypothesis(final_a, final_b, xtest), 'g')
# Out:
# [<matplotlib.lines.Line2D at 0x7f6ce2d3cf28>,
#  <matplotlib.lines.Line2D at 0x7f6ce2d49048>]

# %%
accuracy=(1-err)*100
accuracy
# Out:
# 79.56038401895255
